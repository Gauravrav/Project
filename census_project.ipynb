# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("census.csv",skipinitialspace=True)
# sometimes we will get errors---> column not found
# 'education' ---> ' education' 
# before skipinitialspace=True we had last column as ' '---> correct? 
# now Unnamed:14 ---> the column name has changed

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country Unnamed: 14
# 0          2174             0              40  United-States       <=50K
# ...

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Unnamed: 14'],
#       dtype='object')

# %%
income=data['Unnamed: 14']

# %%
data['income']=income

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country Unnamed: 14  \
# 0          2174             0              40  United-States       <=50K
# ...

# %%
data['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
data.rename(columns={'Unnamed: 14':'income'},inplace=True)

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income income
# 0          2174             0              40  United-States  <=50K  <=50K
# ...

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income', 'income'],
#       dtype='object')

# %%
# we have a column marital-status'
# marital status

# %%
data.columns=data.columns.str.replace('-',' ')

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education num',
#        'marital status', 'occupation', 'relationship', 'race', 'sex',
#        'capital gain', 'capital loss', 'hours per week', 'native country',
#        'income', 'income'],
#       dtype='object')

# %%
#eda

# %%
data['workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
data['workclass'].nunique()
# Out:
# 9

# %%
data['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# income            0
# dtype: int64

# %%
data= data.replace('?',np.nan)

# %%
data.head(16)
# Out:
#     age         workclass  fnlwgt     education  education-num  \
# 0    39         State-gov   77516     Bachelors             13
# 1    50  Self-emp-not-inc   83311     Bachelors             13
# 2    38           Private  215646       HS-grad              9
# 3    53           Private  234721          11th              7
# 4    28           Private  338409     Bachelors             13
# 5    37           Private  284582       Masters             14
# 6    49           Private  160187           9th              5
# 7    52  Self-emp-not-inc  209642       HS-grad              9
# 8    31           Private   45781       Masters             14
# 9    42           Private  159449     Bachelors             13
# 10   37           Private  280464  Some-college             10
# 11   30         State-gov  141297     Bachelors             13
# 12   23           Private  122272     Bachelors             13
# 13   32           Private  205019    Assoc-acdm             12
# ...

# %%
#unique()---> gives me all unique data
#nunique----> gibves me count of unique values

# %%
#null values

# %%
data.isna().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# income               0
# income               0
# dtype: int64

# %%
data.shape
# Out:
# (32561, 15)

# %%
data=data.dropna()

# %%
data.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education num     0
# marital status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital gain      0
# capital loss      0
# hours per week    0
# native country    0
# income            0
# dtype: int64

# %%
data.shape
# the data is huge and amount of null values is less ---> we dropped the data(15-20)
# if data too small dont drop
# Out:
# (30162, 15)

# %%
# data manipulation

# %%
##Extractracting the “education” column and store it in “census_ed” .

# %%
census_ed = data[['education']]
census_ed
# Out:
#         education
# 0       Bachelors
# 1       Bachelors
# 2         HS-grad
# 3            11th
# 4       Bachelors
# ...           ...
# 32556  Assoc-acdm
# 32557     HS-grad
# 32558     HS-grad
# 32559     HS-grad
# 32560     HS-grad
#
# [30162 rows x 1 columns]

# %%
#) Extracting all the columns from “age” to “relationship” and store it in “census_seq”.

# %%
census_seq=data.iloc[:,:8]
census_seq

# [start_row:end_row, start_coplumn:end_column]
# Out:
#        age         workclass  fnlwgt   education  education num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital status         occupation   relationship
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
census_seq = data.loc[:,:'relationship']
census_seq
# Out:
#        age         workclass  fnlwgt   education  education num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital status         occupation   relationship
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
##Extract the column number “0”, “5”, “6” and store it in “census_col”.

# %%
census_col=data.iloc[:,[0,5,6]]
census_col
# Out:
#        age      marital status         occupation
# 0       39       Never-married       Adm-clerical
# 1       50  Married-civ-spouse    Exec-managerial
# 2       38            Divorced  Handlers-cleaners
# 3       53  Married-civ-spouse  Handlers-cleaners
# 4       28  Married-civ-spouse     Prof-specialty
# ...    ...                 ...                ...
# 32556   27  Married-civ-spouse       Tech-support
# 32557   40  Married-civ-spouse  Machine-op-inspct
# 32558   58             Widowed       Adm-clerical
# 32559   22       Never-married       Adm-clerical
# 32560   52  Married-civ-spouse    Exec-managerial
#
# [30162 rows x 3 columns]

# %%
##) Ectracting all the male employees who work in state-gov and store it in “male_gov”.

# %%
male_gov=data[(data['sex']=='Male') & (data['workclass']=='State-gov')]
male_gov
# Out:
#        age  workclass  fnlwgt     education  education num  \
# 0       39  State-gov   77516     Bachelors             13
# 11      30  State-gov  141297     Bachelors             13
# 34      22  State-gov  311512  Some-college             10
# 48      41  State-gov  101603     Assoc-voc             11
# 123     29  State-gov  267989     Bachelors             13
# ...    ...        ...     ...           ...            ...
# 32163   36  State-gov  135874     Bachelors             13
# 32241   45  State-gov  231013     Bachelors             13
# 32321   54  State-gov  138852       HS-grad              9
# 32324   42  State-gov  138162  Some-college             10
# 32360   58  State-gov  200316       HS-grad              9
#
#            marital status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# 11     Married-civ-spouse   Prof-specialty        Husband  Asian-Pac-Islander
# ...

# %%
col=#  instead olf all column try to esxxtract only sex and workclass
for i in col:
    if(data[i]=='Male' and data[i]=='Husband'):
        print(i)
# Out:
#   Input In [7]
#     col=#  instead olf all column try to esxxtract only sex and workclass
#         ^
# SyntaxError: invalid syntax

# %%
|#Extract all the 39 year olds who either have a bachelor's degree or who are native of the United States and store the result in “census_us”.
#We are writing a condition where age should be 39 and storing it in census. This condition is then taken and applied on the 
#next ont to get the result.

# %%
census_us=data[(data["age"]==39) & ((data["education"]=='Bachelors') | (data["native country"]=='United-States'))]
census_us
# Out:
#        age         workclass  fnlwgt     education  education num  \
# 0       39         State-gov   77516     Bachelors             13
# 28      39           Private  367260       HS-grad              9
# 129     39           Private  365739  Some-college             10
# 166     39       Federal-gov  235485    Assoc-acdm             12
# 320     39  Self-emp-not-inc  174308       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 32146   39           Private  117381  Some-college             10
# 32260   39       Federal-gov  232036  Some-college             10
# 32428   39       Federal-gov  110622     Bachelors             13
# 32468   39  Self-emp-not-inc  193689       HS-grad              9
# 32545   39         Local-gov  111499    Assoc-acdm             12
#
#            marital status        occupation   relationship  \
# 0           Never-married      Adm-clerical  Not-in-family
# ...

# %%
#sample() helps us to get random rows

# %%
census_200 = data.sample(200)
census_200
# Out:
#        age     workclass  fnlwgt     education  education num  \
# 10919   53     State-gov   43952       Masters             14
# 26507   19       Private   95078       HS-grad              9
# 23454   37       Private  161141       HS-grad              9
# 14173   40  Self-emp-inc  102226       HS-grad              9
# 5913    18       Private   98667          11th              7
# ...    ...           ...     ...           ...            ...
# 9389    31     Local-gov  144949       HS-grad              9
# 28581   19       Private   96483       HS-grad              9
# 17856   57       Private  237691       HS-grad              9
# 30841   37       Private  238433       1st-4th              2
# 31344   45       Private  137604  Some-college             10
#
#            marital status         occupation   relationship  \
# 10919  Married-civ-spouse    Exec-managerial        Husband
# 26507       Never-married       Adm-clerical      Own-child
# ...

# %%
#calculating % of married people

# %%
cal = data[(data['marital status']=='Married-civ-spouse') | (data['marital status']== 'Married-AF-spouse')]

(len(cal)/len(data))*100
# Out:
# 46.7011471387839

# %%
data[(data['marital status']=='Married-spouse-absent') | (data['marital status']=='Married-AF-spouse') |(data['marital status']=='Married-civ-spouse')]['marital status'].count()/data.shape[0]*100
# Out:
# 47.92785624295471

# %%
total=len(data['marital status'])

# %%
data['marital status'].value_counts()
# Out:
# Married-civ-spouse       14065
# Never-married             9726
# Divorced                  4214
# Separated                  939
# Widowed                    827
# Married-spouse-absent      370
# Married-AF-spouse           21
# Name: marital status, dtype: int64

# %%
m=14065+21+370

# %%
p=(m/total)

# %%
p
# Out:
# 0.47927856242954714

# %%
p*100
# Out:
# 47.92785624295471

# %%
# linear regression

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital gain  capital loss  hours per week native country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# for linear regression 
# independent --> education num
# dependent ---->hours per week

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30162 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30162 non-null  int64
#  1   workclass       30162 non-null  object
#  2   fnlwgt          30162 non-null  int64
#  3   education       30162 non-null  object
#  4   education num   30162 non-null  int64
#  5   marital status  30162 non-null  object
#  6   occupation      30162 non-null  object
#  7   relationship    30162 non-null  object
#  8   race            30162 non-null  object
#  9   sex             30162 non-null  object
#  10  capital gain    30162 non-null  int64
#  11  capital loss    30162 non-null  int64
#  12  hours per week  30162 non-null  int64
#  13  native country  30162 non-null  object
#  14  income          30162 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 4.7+ MB

# %%
x= data[['education num']]
y= data['hours per week']
from sklearn.linear_model import *
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([40.1516711 , 38.07360531, 42.92242549, ..., 40.1516711 ,
#        38.7662939 , 40.1516711 ])

# %%
from sklearn.metrics import *

# %%
accuracy = r2_score(y_test,y_pred)
accuracy
# Out:
# 0.02781973266918525

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 134.69130460518096

# %%
#logistic

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital gain  capital loss  hours per week native country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# here we will take occupation --> indep
# 0income --> dep

# %%
x=data['occupation']
x=pd.DataFrame(x)

# %%
x
# Out:
#               occupation
# 0           Adm-clerical
# 1        Exec-managerial
# 2      Handlers-cleaners
# 3      Handlers-cleaners
# 4         Prof-specialty
# ...                  ...
# 32556       Tech-support
# 32557  Machine-op-inspct
# 32558       Adm-clerical
# 32559       Adm-clerical
# 32560    Exec-managerial
#
# [30162 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l=LabelEncoder()

# %%
x=l.fit_transform(x)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
x
# Out:
# array([0, 3, 5, ..., 0, 0, 3])

# %%
x=pd.DataFrame(x)

# %%
x
# Out:
#         0
# 0       0
# 1       3
# 2       5
# 3       5
# 4       9
# ...    ..
# 30157  12
# 30158   6
# 30159   0
# 30160   0
# 30161   3
#
# [30162 rows x 1 columns]

# %%
data['income'].value_counts()
# Out:
# <=50K    22654
# >50K      7508
# Name: income, dtype: int64

# %%
y=data['income'].replace('<=50K',0).replace('>50K',1)

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: income, Length: 30162, dtype: int64

# %%
from sklearn.linear_model import *
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)

# %%
lo=LogisticRegression()

# %%
lo.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lo.predict(x_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7480384572880981

# %%
# this model is performing better then previous model

# %%
# decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital gain  capital loss  hours per week native country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
data['education'].value_counts()
# Out:
# HS-grad         9840
# Some-college    6678
# Bachelors       5044
# Masters         1627
# Assoc-voc       1307
# 11th            1048
# Assoc-acdm      1008
# 10th             820
# 7th-8th          557
# Prof-school      542
# 9th              455
# 12th             377
# Doctorate        375
# 5th-6th          288
# 1st-4th          151
# Preschool         45
# Name: education, dtype: int64

# %%
data.education= data.education.replace(['Preschool', '1st-4th', '5th-6th', '7th-8th', '9th','10th', '11th', '12th'], 'School')
data.education = data.education.replace(['Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Some-college'], 'Higher')

# %%
data=data.apply(l.fit_transform)

# %%
data.head(1)
# Out:
#    age  workclass  fnlwgt  education  education num  marital status  \
# 0   22          5    2491          0             12               1
#
#    occupation  relationship  race  sex  capital gain  capital loss  \
# 0           0             1     4    1            24             0
#
#    hours per week  native country  income
# 0              39              38       0

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
x
# Out:
#        age  workclass  fnlwgt  education  education num  marital status  \
# 0       22          5    2491          0             12               1
# 1       33          4    2727          0             12               0
# 2       21          2   13188          2              8               2
# 3       36          2   14354          5              6               0
# 4       11          2   18120          0             12               0
# ...    ...        ...     ...        ...            ...             ...
# 32556   10          2   15471          3             11               0
# 32557   23          2    7555          2              8               0
# 32558   41          2    7377          2              8               2
# 32559    5          2   12060          2              8               1
# 32560   35          3   16689          2              8               0
#
#        occupation  relationship  race  sex  capital gain  capital loss  \
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: income, Length: 30162, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8059454083324125

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=300)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
y_pred=rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8579953586031606

# %%
# for this datasett rf is giving the best accuracy score
